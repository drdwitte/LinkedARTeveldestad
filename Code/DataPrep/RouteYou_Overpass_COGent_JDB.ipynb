# %% [markdown]
# # RouteYou interfacing for COGENT

# %%
ROUTEYOU_KEY = '<FILL IN>'

# %%
import requests
from random import randint
import json

class RouteYou_Json_Client:
    key = None
    def __init__(self, service, version, timeout = 10, token = None):
        self.url = 'http://api.routeyou.com/%version%/json/%service%/%session%/worker'
        self.key = RouteYou_Json_Client.key
        self.token = token
        
        self._service = service
        self._version = version
        self._timeout = timeout
        
        self._needsToken = True
        self._httpClient = None
    def __getattr__(self, name):
        #magic function to call methods in RouteYou webservice
        def wrapper(*args, **kwargs):
            return self._execurteCall(name, args)
        return wrapper
    def _getHttpClient(self):
        self.url = self.url.replace('%service%',self._service)
        self.url = self.url.replace('%version%',self._version)
        if self.token is None:
            self.url = self.url.replace('%session%','k-' + self.key)
        else:
            self.url = self.url.replace('%session%',self.token)
    def _execurteCall(self, method, params, retry = False):
        self._getHttpClient()
        id = randint(1,1000) 
        data = {
            'jsonrpc' : self._version,
            'id' : id,
            'method' : method,
            'params' : params
            }     

        req = requests.post(self.url, json.dumps(data))
        response = req.json()
        if req.status_code == 200:
            return response
        else:
            print (req.status_code)
            return False
    def getKey(self):
        return self.key

RouteYou_Json_Client.key = ROUTEYOU_KEY

# %% [markdown]
# ## POIs
#
# https://help.routeyou.com/en/topic/view/622/poi-web-service-2-0
#
# Main problem, we cannot create POIs ourselves.

# %%
import math

# Automatically calculate a bounding box based on lat, lon and a radius
class BoundingBox(object):
    def __init__(self, *args, **kwargs):
        self.lat_min = None
        self.lon_min = None
        self.lat_max = None
        self.lon_max = None


def get_bounding_box(latitude_in_degrees, longitude_in_degrees, half_side_in_km):
    assert latitude_in_degrees >= -90.0 and latitude_in_degrees  <= 90.0
    assert longitude_in_degrees >= -180.0 and longitude_in_degrees <= 180.0

    lat = math.radians(latitude_in_degrees)
    lon = math.radians(longitude_in_degrees)

    radius  = 6371
    # Radius of the parallel at given latitude
    parallel_radius = radius*math.cos(lat)

    lat_min = lat - half_side_in_km/radius
    lat_max = lat + half_side_in_km/radius
    lon_min = lon - half_side_in_km/parallel_radius
    lon_max = lon + half_side_in_km/parallel_radius
    rad2deg = math.degrees

    box = BoundingBox()
    box.lat_min = rad2deg(lat_min)
    box.lon_min = rad2deg(lon_min)
    box.lat_max = rad2deg(lat_max)
    box.lon_max = rad2deg(lon_max)

    return (box)

# %%
# Regio van de oude kwaremont
heli_location_lat = 50.7767526525832
heli_location_lon = 3.521515819672684

heli_bbox = get_bounding_box(heli_location_lat, heli_location_lon, 2)
ghent_bbox = BoundingBox()
ghent_bbox.lat_min = 51.053083
ghent_bbox.lon_min = 3.711850
ghent_bbox.lat_max = 51.055882
ghent_bbox.lon_max = 3.719387

# %%
#example call to route webservice 2.0
# Center of Ghent: 3.721114,51.052071,3.757249,51.060831
poiService = RouteYou_Json_Client('poi', '2.0')
print(poiService.search({'bounds': {'min': {'lat': heli_bbox.lat_min, 'lon': heli_bbox.lon_min}, 'max': {'lat': heli_bbox.lat_max, 'lon': heli_bbox.lon_max}}})['result'])
# Out:
# [{'id': 1602181, 'location': {'id': 47503560}, 'type': {'id': 239, 'name': {'es': 'Pendiente', 'fr': 'Chantier', 'ca': 'Pendent', 'nl': 'Helling', 'de': 'Steigung', 'it': None, 'en': 'Slope'}, 'languages': ['es', 'fr', 'ca', 'nl', 'de', 'it', 'en'], 'category': {'id': 2}}, 'owner': {'id': 165089, 'flag': None, 'avatarRevision': 1, 'logoRevision': 0, 'headerRevision': 0, 'name': {'nl': 'Wikipedia'}, 'languages': ['nl'], 'permission': {'writable': False}}, 'permission': {'id': 0, 'read': 'public', 'write': 'group', 'writable': False}, 'centroid': {'wkt': 'POINT(3.529 50.769)'}, 'bounds': {'wkt': 'BOX(3.529 50.769,3.529 50.769)'}, 'flag': 'be', 'score': 0.794, 'commercialScore': 0, 'configuration': None, 'media': [{'owner': {'id': 165089}, 'score': 0.752753, 'copyright': {'id': 6}, 'width': {'de': 450, 'en': 450, 'it': 450, 'fr': 450, 'es': 450, 'ca': 450, 'nl': 450}, 'infoUri': {'de': None, 'en': None, 'it': None, 'fr': None, 'es': None, 'ca': None, 'nl': None}, 'id': 812658, 'source': {'name': {'de': 'John.john.59', 'en': 'John.john.59', 'it': 'John.john.59', 'fr': 'John.john.59', 'es': 'John.john.59', 'ca': 'John.john.59', 'nl': 'John.john.59'}, 'uri': {'de': 'https://fr.wikipedia.org/w/index.php?curid=3079199#/media/Fichier:Vieux_Quaremont_Tour_des_Flandres.jpg', 'en': 'https://fr.wikipedia.org/w/index.php?curid=3079199#/media/Fichier:Vieux_Quaremont_Tour_des_Flandres.jpg', 'it': 'https://fr.wikipedia.org/w/index.php?curid=3079199#/media/Fichier:Vieux_Quaremont_Tour_des_Flandres.jpg', 'fr': 'https://fr.wikipedia.org/w/index.php?curid=3079199#/media/Fichier:Vieux_Quaremont_Tour_des_Flandres.jpg', 'es': 'https://fr.wikipedia.org/w/index.php?curid=3079199#/media/Fichier:Vieux_Quaremont_Tour_des_Flandres.jpg', 'ca': 'https://fr.wikipedia.org/w/index.php?curid=3079199#/media/Fichier:Vieux_Quaremont_Tour_des_Flandres.jpg', 'nl': 'https://fr.wikipedia.org/w/index.php?curid=3079199#/media/Fichier:Vieux_Quaremont_Tour_des_Flandres.jpg'}}, 'type': {'id': 1}, 'content': {'de': '37c1cb5e64f6a9e43588d2c8d81ef3e8_422a6f0b51d86d4c70217c56918c199af2aa6376.jpg', 'en': '37c1cb5e64f6a9e43588d2c8d81ef3e8_422a6f0b51d86d4c70217c56918c199af2aa6376.jpg', 'it': '37c1cb5e64f6a9e43588d2c8d81ef3e8_422a6f0b51d86d4c70217c56918c199af2aa6376.jpg', 'fr': '37c1cb5e64f6a9e43588d2c8d81ef3e8_422a6f0b51d86d4c70217c56918c199af2aa6376.jpg', 'es': '37c1cb5e64f6a9e43588d2c8d81ef3e8_422a6f0b51d86d4c70217c56918c199af2aa6376.jpg', 'ca': '37c1cb5e64f6a9e43588d2c8d81ef3e8_422a6f0b51d86d4c70217c56918c199af2aa6376.jpg', 'nl': '37c1cb5e64f6a9e43588d2c8d81ef3e8_422a6f0b51d86d4c70217c56918c199af2aa6376.jpg'}, 'height': {'de': 600, 'en': 600, 'it': 600, 'fr': 600, 'es': 600, 'ca': 600, 'nl': 600}, 'languages': ['de', 'en', 'it', 'fr', 'es', 'ca', 'nl']}], 'infoUri': {'de': 'https://de.wikipedia.org/wiki/Oude Kwaremont', 'en': 'https://en.wikipedia.org/wiki/Oude Kwaremont', 'it': 'https://it.wikipedia.org/wiki/Oude Kwaremont', 'fr': 'https://fr.wikipedia.org/wiki/Vieux Quaremont', 'ca': 'https://ca.wikipedia.org/wiki/Oude Kwaremont', 'es': 'https://es.wikipedia.org/wiki/Oude Kwaremont', 'nl': 'https://nl.wikipedia.org/wiki/Oude Kwaremont'}, 'name': {'es': 'Oude Kwaremont', 'fr': 'Vieux Quaremont', 'ca': 'Oude Kwaremont', 'nl': 'Oude Kwaremont', 'de': 'Oude Kwaremont', 'it': 'Oude Kwaremont', 'en': 'Oude Kwaremont'}, 'languages': ['es', 'fr', 'ca', 'nl', 'de', 'it', 'en']}, {'id': 7493244, 'location': {'id': 48176205}, 'type': {'id': 239, 'name': {'fr': 'Chantier', 'nl': 'Helling', 'de': 'Steigung', 'en': 'Slope'}, 'languages': ['fr', 'nl', 'de', 'en'], 'category': {'id': 2}}, 'owner': {'id': 607725, 'flag': 'be', 'avatarRevision': 1, 'logoRevision': 0, 'headerRevision': 0, 'name': {'en': 'Cols&Climbs@RouteYou'}, 'languages': ['en'], 'permission': {'writable': False}}, 'permission': {'id': 0, 'read': 'public', 'write': 'group', 'writable': False}, 'centroid': {'wkt': 'POINT(3.5489464 50.7820642)'}, 'bounds': {'wkt': 'BOX(3.54402 50.78206,3.54895 50.78271)'}, 'flag': 'be', 'score' ...

# %% [markdown]
# Let's start with a bounding box of Ghent ( http://bboxfinder.com/#51.029298,3.687458,51.066335,3.753204)
#   3.687458,51.029298,3.753204,51.066335

# %%
gent_lat = (51.029298, 61.066335)
gent_lon = (3.687458, 4.753204)

poiService = RouteYou_Json_Client('poi', '2.0')
poi_collection = poiService.search({
    "bounds": {
        "min": {
          "lat": gent_lat[0],
          "lon": gent_lon[0]
        }, 
        "max": {
          "lat": gent_lat[1],
          "lon": gent_lon[1]
        }
    },
    "limit": 50,
    "offset": 100 
})

# %%
def printkeys(json):
  for k in json:
    print(k)
  return

def printPOI(result):
  print(
    result['type']['name']['nl']
  )
  print(
    result['centroid']['wkt']
  )
  print(
    result['name']['nl']
  )

  return

# %% [markdown]
# ### Manual exploration of the results

# %%
pois = poi_collection['result']
print(len(pois))
#waarom maar 10?

for p in pois:
  printPOI(p)
  print()
# Out:
# 10
# Begraafplaats
# POINT(4.3682325241382 51.165612279607)
# Domein Schoonselhof
#
# Historische plaats
# POINT(3.72590278 51.04258611)
# Sint-Pietersplein
#
# Toren
# POINT(3.72583333 51.04472222)
# Boekentoren
#
# Stadhuis
# POINT(3.725447 51.054375)
# Stadhuis
#
# Kathedraal
# POINT(4.40152750635985 51.2203551655474)
# Onze-Lieve-Vrouwe-Kathedraal
#
# Winkelstraat
# POINT(4.4091154 51.2180888)
# Meir
#
# Treinstation
# POINT(4.4207019 51.2169691)
# Station Antwerpen-Centraal
#
# Plein
# POINT(3.723979 51.0501559)
# Kouter
#
# Museum
# POINT(4.14480149745941 51.1673897834844)
# Mercatormuseum
#
# Stadhuis
# POINT(4.39915825396729 51.2214601529109)
# Grote Markt en stadhuis

# %% [markdown]
# # Routing
#
# https://help.routeyou.com/en/topic/view/430/routing-web-service-2-0#route
#
# Creating a route, main problem we can only provide maximum 2 via-points.
#
# Available routingids
#
#     15: recreational cycling - nicest
#     28: race cycling - nicest
#     29: recreational cycling - shortest
#     30: race cycling - shortest
#     31: hiking - nicest
#     32: race cycling - shortest (avoid cobblestones)
#     33: race cycling - nicest (avoid cobblestones)
#     34: inline skating - nicest
#     35: inline skating - shortest
#     36: gravel bike - nicest (winter)
#     37: gravel bike - shortest (winter)
#     38: node-to-node cycling
#     39: gravel bike - nicest (summer)
#     40: gravel bike - shortest (summer)
#     47: MTB Sport Vlaanderen - shortest (all directions)
#     48: MTB Sport Vlaanderen - shortest
#     49: motor - nicest
#     50: motor - shortest
#     51: motor - fastest
#     53: mountain bike - nicest
#     54: node-to-node cycling (only paved)
#     55: horse - node network
#     63: hiking - node network
#     76: recreational cycling - nicest (avoid unpaved)
#     80: shortest - OSM (all ways)
#     94: race cycling - nicest (with car)
#     95: race cycling - shortest (with car)
#     96: recreational cycling - shortest (only paved)
#     97: mountain bike - shortest
#     98: hiking - shortest
#     99: node-to-node cycling (avoid slopes)

# %%
# Route from AA-tower to Gravensteen
# 51.013135455152295, 3.709584074567241 --> 51.05752102565761, 3.7209650134626404
routeService = RouteYou_Json_Client('routing', '2.0')
print(routeService.route([{'lon': 3.709584074567241, 'lat': 51.013135455152295},{'lon': 3.7209650134626404, 'lat': 51.05752102565761}], 31, {'add': {'elevation': True, 'instructions': True}, 'newInstructionFormat': True}))
# Out:
# {'result': {'name': {'en': 'No title'}, 'nameGenerated': {'en': True}, 'subName': {'en': None}, 'description': {'en': 'Routing: Hiking - nicest'}, 'descriptionGenerated': {'en': True}, 'begin': {'wkt': 'POINT(3.70958 51.01312)'}, 'end': {'wkt': 'POINT(3.72113 51.05755)'}, 'length': 7076.8765314185375, 'bounds': {'wkt': 'BOX(3.70436 51.01132,3.72341 51.05755)'}, 'score': 0, 'beginAddress': None, 'endAddress': None, 'languages': ['en'], 'type': {'id': 0, 'name': {'en': 'All routes'}}, 'media': [], 'infoUri': {'en': None}, 'duration': 580927, 'geometry': {'google': '_ojvH{osU?p@X?Ff@T?V@V~@Pb@b@x@j@x@\\Z~BbBOXYz@C`@?xAA~EHvBEVOPCJc@]{AqAOM[GKK}BuEq@eAgCgCs@_@WYeG_Dk@]q@_@uFsC_@CyAa@}@I{@?UBA?[Cy@DQJg@@mEX{ABqBES?Uu@MCSs@mCmIgAkDwCeJyB_HoFuP[eA}A_FM_@MEKYIDCGIWESsBsGK_@cCO_BW}CSg@Iq@SqEYi@KiAg@cDgB{BtPgBAH]Jo@QYkBmIyFfNETO~@?\\@NGBI?EfAOMO@[Tm@r@{@BYE]QKOEH[P]XJ`A@Rm@JI@o@HOJi@j@I[m@FMHQTIDKEUSUI[Ca@Cg@s@{@u@EF]DENYWI\\yCcCkBfIQh@KCqBd@_@@{BmAq@cAQ`@GUGKMGs@`BkBaIUq@kB{DOQe@[eAe@s@?iENuBRB`Ba@DO@m@@uJz@aCAgBIuAQQIgBcAo@Ym@SqBS@SAq@?OkDF_BFkALIEKHSBq@ByAMe@SmA{@]s@m@_Ao@sAa@d@a@b@aAn@u@`@oB|@'}, 'instructions': [{'geometry': {'wkt': 'POINT(3.70958 51.01312)'}, 'distance': 0, 'time': None, 'type': {'id': 1}, 'street': '', 'bearing': {'from': None, 'to': -89.99990283913307}, 'angle': None, 'importance': 1, 'index': 0}, {'geometry': {'wkt': 'POINT(3.70933 51.01312)'}, 'distance': 17.544469573875084, 'time': None, 'type': {'id': 6}, 'street': '', 'bearing': {'from': -89.99990283913307, 'to': 180}, 'angle': -90.00009716086691, 'importance': 1, 'index': 1}, {'geometry': {'wkt': 'POINT(3.70933 51.01299)'}, 'distance': 32.00677807061769, 'time': None, 'type': {'id': 7}, 'street': '', 'bearing': {'from': 180, 'to': -107.63496739804727}, 'angle': 72.36503260195275, 'importance': 1, 'index': 2}, {'geometry': {'wkt': 'POINT(3.70913 51.01295)'}, 'distance': 46.73092932165912, 'time': None, 'type': {'id': 6}, 'street': '', 'bearing': {'from': -107.63496739804727, 'to': 180}, 'angle': -72.36503260195275, 'importance': 1, 'index': 3}, {'geometry': {'wkt': 'POINT(3.70913 51.01284)'}, 'distance': 58.96826694298477, 'time': None, 'type': {'id': 1}, 'street': '', 'bearing': {'from': 180, 'to': -176.9987882034973}, 'angle': 3.00121179650273, 'importance': 1, 'index': 4}, {'geometry': {'wkt': 'POINT(3.70912 51.01272)'}, 'distance': 72.33652270958454, 'time': None, 'type': {'id': 7}, 'street': '', 'bearing': {'from': -176.9987882034973, 'to': -120.79665892219622}, 'angle': 56.20212928130108, 'importance': 1, 'index': 5}, {'geometry': {'wkt': 'POINT(3.7088 51.0126)'}, 'distance': 98.4620090635199, 'time': None, 'type': {'id': 1}, 'street': '', 'bearing': {'from': -120.79665892219622, 'to': -128.4749011860723}, 'angle': -7.678242263876072, 'importance': 1, 'index': 6}, {'geometry': {'wkt': 'POINT(3.70833 51.01233)'}, 'distance': 143.13244019327155, 'time': None, 'type': {'id': 1}, 'street': '', 'bearing': {'from': -134.61196266030885, 'to': -140.3296053646571}, 'angle': -5.717642704348265, 'importance': 1, 'index': 8}, {'geometry': {'wkt': 'POINT(3.7079 51.01196)'}, 'distance': 194.328316752941, 'time': None, 'type': {'id': 16}, 'street': '', 'bearing': {'from': -149.57792190534497, 'to': -153.8241568524533}, 'angle': -4.2462349471083485, 'importance': 1, 'index': 10}, {'geometry': {'wkt': 'POINT(3.7074 51.01132)'}, 'distance': 273.704732058215, 'time': None, 'type': {'id': 9}, 'street': '', 'bearing': {'from': -153.8241568524533, 'to': -45.63439501192725}, 'angle': 108.18976184052606, 'importance': 1, 'index': 11}, {'geometry': {'wkt': 'POINT(3.70727 51.0114)'}, 'distance': 286.45014501903233, 'time': None, 'type': {'id': 1}, 'street': '', 'bearing': {'from': -45.63439501192725, 'to': -55.44300104052042}, 'angle': -9.808606028593168, 'importance': 1, 'index': 12}, {'geometry': {'wkt': 'POINT(3.7068 51.01155)'}, 'distance': 324.1292721038521, 'time': None, 'type': {'id': 16}, 'street': '', 'bearing': {'from': -79.40853521426567, 'to': -89.99982511339921},  ...

# %% [markdown]
# ## Google Places API
#
# https://github.com/googlemaps/google-maps-services-python
#
# We need an API key to use them!

# %%
! pip install -U googlemaps

# %% [markdown]
# ## Overpass queries
#
# Overview of different amenities
# https://wiki.openstreetmap.org/wiki/Key:amenity
#
# Cultural heritage related ones https://wiki.openstreetmap.org/wiki/Key:amenity#Entertainment,_Arts_&_Culture

# %%
# !pip install overpy
# !pip install geojson
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting overpy
#   Downloading overpy-0.6.tar.gz (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 KB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: overpy
#   Building wheel for overpy (setup.py) ... done
#   Created wheel for overpy: filename=overpy-0.6-py3-none-any.whl size=14107 sha256=5e0864d9290a86ce34902604c3e964755e240d3b6b830d31e46183c9675d40cf
#   Stored in directory: /root/.cache/pip/wheels/69/6f/9b/c4e56235399fbce16dfcd71a65bd2af0e5882684cc4fa2ec70
# Successfully built overpy
# Installing collected packages: overpy
# Successfully installed overpy-0.6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geojson
#   Downloading geojson-3.0.1-py3-none-any.whl (15 kB)
# Installing collected packages: geojson
# Successfully installed geojson-3.0.1

# %%
GHENT_BBOX = (51.029,3.67, 51.067,3.76)
query = f"""
            (
            node
                ['amenity']
                {GHENT_BBOX};
            node
                ['shop']
                {GHENT_BBOX};
            way
                ['shop']
                {GHENT_BBOX};
            way
                ['amenity']
                {GHENT_BBOX};
            relation
                ['amenity']
                {GHENT_BBOX};
            relation
                ['shop']
                {GHENT_BBOX};
            );
            out geom;
"""

park_query = f"""
            (
                node
                    ['leisure'='park']
                    {GHENT_BBOX};
                way
                    ['leisure'='park']
                    {GHENT_BBOX};
                relation
                    ['leisure'='park']
                    {GHENT_BBOX};
            );
            out geom;
"""

tourism_query = f"""
            (
                node
                    ['tourism']
                    {GHENT_BBOX};
                
            );
            out geom;
"""

# %%
import overpy
import geojson

api = overpy.Overpass()

# fetch all ways and nodes
#result = api.query(park_query)
result = api.query(tourism_query)
output = []

for node in result.nodes:
    print(node.tags)
    print(f"{node.tags['name'] if 'name' in node.tags else None} ({node.tags['amenity'] if 'amenity' in node.tags else None})")
    print(f"\t Lat: {node.lat}, Lon: {node.lon}")

    output_line = node.tags
    output_line['coordinate'] = {'latitude': float(node.lat), 'longitude': float(node.lon)}

    output.append(output_line)
    print()
# Out:
# {'addr:housenumber': '43', 'addr:postcode': '9000', 'addr:street': 'Jozef Guislainstraat', 'email': 'info@museumdrguislain.be', 'fee': 'yes', 'name': 'Museum Dr. Guislain', 'opening_hours': 'Tu-Fr 09:00-17:00; Sa-Su 13:00-17:00', 'phone': '+32 9 398 69 50', 'toilets:wheelchair': 'yes', 'tourism': 'museum', 'website': 'http://www.museumdrguislain.be', 'wheelchair': 'yes', 'wikidata': 'Q2934898', 'wikimedia_commons': 'Category:Museum_Dr_Guislain'}
# Museum Dr. Guislain (None)
# 	 Lat: 51.0668514, Lon: 3.7033213
#
# {'tourism': 'artwork', 'wikidata': 'Q107482658'}
# None (None)
# 	 Lat: 51.0313179, Lon: 3.7195611
#
# {'artwork_type': 'statue', 'name': 'Ros Beiaard', 'subject:wikidata': 'Q658782', 'tourism': 'artwork', 'wikidata': 'Q88889022'}
# Ros Beiaard (None)
# 	 Lat: 51.0317241, Lon: 3.7177118
#
# {'brand': 'Ibis', 'brand:wikidata': 'Q920166', 'name': 'Ibis Gent Centrum Opera', 'operator': 'Ibis', 'tourism': 'hotel'}
# Ibis Gent Centrum Opera (None)
# 	 Lat: 51.0484729, Lon: 3.7211612
#
# {'name': 'Ghent River Hotel', 'tourism': 'hotel', 'website': 'http://www.ghent-river-hotel.be/'}
# Ghent River Hotel (None)
# 	 Lat: 51.0581732, Lon: 3.7256482
#
# {'OnroerendErfgoed:criteria': 'BE', 'addr:street': 'Grootkanonplein', 'alt_name': 'Rode Duivel;Groot Kanon', 'heritage': '4', 'heritage:operator': 'OnroerendErfgoed', 'heritage:website': 'https://id.erfgoed.net/erfgoedobjecten/200796', 'historic': 'cannon', 'image': 'http://commons.wikimedia.org/wiki/File:Ghent_cannon.jpg', 'name': 'Dulle Griet', 'ref:OnroerendErfgoed': '200796', 'start_date': 'mid C15..1783', 'tourism': 'attraction', 'wikidata': 'Q686236', 'wikipedia': 'nl:Dulle Griet (kanon)'}
# Dulle Griet (None)
# 	 Lat: 51.0573042, Lon: 3.7241156
#
# {'artist:wikidata': 'Q1875108', 'artist_name': 'Pieter De Vigne', 'artwork_type': 'statue', 'historic': 'memorial', 'image': 'http://commons.wikimedia.org/wiki/File:Jacob_van_Artevelde_statue_in_Vrijdagmarkt_square.JPG', 'mapillary': '932492370870870', 'name': 'Jacob van Artevelde', 'subject:wikidata': 'Q359165', 'subject:wikipedia': 'nl:Jacob van Artevelde', 'tourism': 'artwork', 'wikidata': 'Q22032062'}
# Jacob van Artevelde (None)
# 	 Lat: 51.0569844, Lon: 3.7256398
#
# {'addr:housenumber': '10', 'addr:street': 'Korenlei', 'brand': 'Marriott', 'brand:wikidata': 'Q1141173', 'name': 'Marriott Ghent', 'operator': 'Marriott', 'operator:website': 'http://www.marriott.com/', 'phone': '+32 9 233 93 93', 'stars': '4', 'tourism': 'hotel'}
# Marriott Ghent (None)
# 	 Lat: 51.0551644, Lon: 3.7195449
#
# {'email': 'schoolvantoen@outlook.be', 'fee': 'no', 'name': 'De school van toen', 'opening_hours': 'Mo-Fr 09:00-12:00,14:00-16:00; We 09:00-12:00', 'tourism': 'museum', 'wikidata': 'Q2248967', 'wikipedia': 'nl:De School van Toen'}
# De school van toen (None)
# 	 Lat: 51.0554405, Lon: 3.7172867
#
# {'name': 'Cour St Georges', 'tourism': 'hotel'}
# Cour St Georges (None)
# 	 Lat: 51.0545735, Lon: 3.7257844
#
# {'addr:city': 'Gent', 'addr:housenumber': '37', 'addr:street': 'Kraanlei', 'name': 'Hotel Harmony', 'toilets:wheelchair': 'no', 'tourism': 'hotel', 'wheelchair': 'no'}
# Hotel Harmony (None)
# 	 Lat: 51.0571300, Lon: 3.7227518
#
# {'name': 'Gravensteen', 'tourism': 'hotel'}
# Gravensteen (None)
# 	 Lat: 51.0564685, Lon: 3.7197092
#
# {'addr:housenumber': '26', 'addr:street': 'Jan Palfijnstraat', 'created_by': 'iLOE 1.9', 'guest_house': 'bed_and_breakfast', 'internet_access': 'wlan', 'name': 'Alphabed B&B', 'tourism': 'guest_house', 'website': 'http://www.alphabed.be/'}
# Alphabed B&B (None)
# 	 Lat: 51.0539632, Lon: 3.7298844
#
# {'name': 'Hotel Flandria', 'tourism': 'hotel'}
# Hotel Flandria (None)
# 	 Lat: 51.0540805, Lon: 3.7292616
#
# {'name': 'NH Gent Sint Pieters', 'tourism': 'hotel'}
# NH Gent Sint Pieters (None)
# 	 Lat: 51.0410936, Lon: 3.7099472
#
# {'name': 'De Waterzooi', 'tourism': 'guest_house'}
# De Waterzooi (None)
# 	 Lat: 51.0564822, Lon: 3.7213917
#
# {'name': 'Dampoort', 'tourism': 'hotel'}
# Dampoort (None)
# 	 Lat: 51.0567301, Lon: 3.7422207
#
# {'name': 'Place2stay', 'source_ref': 'http://www.place2stayinghent.be/en/home.htmlhttp://www.place2stayinghent.be/en/home.html', 'tourism': 'hotel'}
# Place2stay (None)
# 	 Lat: 51.0582106, Lon: 3.7265043
#
# {'artwork_type': 'statue', 'description': 'https://commons.wikimedia.org/wiki/File:20110417_Gent_(3).jpg         https://photos.app.goo.gl/MnH4Fd2mXFQ3twZK9', 'image': 'https://images.mapillary.com/Jn7Rq6tpaBeV8bd5wG8aVE/thumb-2048.jpg', 'mapillary': '524292088573372', 'name': 'Hippolyte Metdepenningen', 'subject:wikidata': 'Q2833532', 'tourism': 'artwork', 'wikidata': 'Q89423557'}
# Hippolyte Metdepenningen (None)
# 	 Lat: 51.0501942, Lon: 3.7206663
#
# {'brand': 'Novotel', 'brand:wikidata': 'Q420545', 'name': 'Novotel', 'tourism': 'hotel'}
# Novotel (None)
# 	 Lat: 51.0544316, Lon: 3.7237542
#
# {'information': 'office', 'name': 'Infokantoor Toerisme Gent', 'opening_hours': 'Mo-Su 10:00-18:00', 'tourism': 'information', 'wheelchair': 'yes'}
# Infokantoor Toerisme Gent (None)
# 	 Lat: 51.0562954, Lon: 3.7212016
#
# {'addr:housenumber': '2', 'addr:street': 'Limburgstraat', 'brand': 'Ibis', 'brand:wikidata': 'Q920166', 'internet_access': 'wlan', 'name': 'Ibis Gent Centrum St Baafs Kathedraal', 'phone': '+32 9 233 00 00', 'smoking': 'no', 'tourism': 'hotel'}
# Ibis Gent Centrum St Baafs Kathedraal (None)
# 	 Lat: 51.0528387, Lon: 3.7261984
#
# {'addr:city': 'Gent', 'addr:housenumber': '76', 'addr:postcode': '9000', 'addr:street': 'Wolterslaan', 'name': 'Cuberdon B&B', 'tourism': 'guest_house'}
# Cuberdon B&B (None)
# 	 Lat: 51.0484696, Lon: 3.7494110
#
# {'addr:housenumber': '1', 'addr:postcode': '9000', 'addr:street': 'Nieuwebosstraat', 'name': 'Parkhotel', 'tourism': 'hotel', 'website': 'http://www.parkhotelgent.be'}
# Parkhotel (None)
# 	 Lat: 51.0493736, Lon: 3.7356734
#
# {'addr:city': 'BE', 'addr:housenumber': '9', 'addr:postcode': '9000', 'addr:street': 'Poel', 'name': 'PPP', 'tourism': 'guest_house'}
# PPP (None)
# 	 Lat: 51.0543214, Lon: 3.7171867
#
# {'artist_name': 'Chris De Mangel', 'artwork_type': 'statue', 'historic': 'memorial', 'name': 'De stroppendrager', 'start_date': '2009-09-29', 'tourism': 'artwork'}
# De stroppendrager (None)
# 	 Lat: 51.0595873, Lon: 3.7151932
#
# {'board_type': 'wildlife', 'check_date': '2021-11-02', 'information': 'board', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0580390, Lon: 3.6713197
#
# {'addr:housenumber': '18', 'addr:street': 'Lucas Munichstraat', 'name': 'Bed in Gent', 'tourism': 'guest_house'}
# Bed in Gent (None)
# 	 Lat: 51.0553667, Lon: 3.7356613
#
# {'name': 'Castelnou Aparthotel', 'tourism': 'hotel'}
# Castelnou Aparthotel (None)
# 	 Lat: 51.0495293, Lon: 3.7391171
#
# {'name': 'Museum voor Stenen Voorwerpen', 'tourism': 'museum', 'wheelchair': 'no', 'wikidata': 'Q2195107'}
# Museum voor Stenen Voorwerpen (None)
# 	 Lat: 51.0540032, Lon: 3.7365072
#
# {'artwork_type': 'statue', 'historic': 'memorial', 'name': 'Emile Claus', 'subject:wikidata': 'Q733002', 'tourism': 'artwork', 'wikidata': 'Q99673791'}
# Emile Claus (None)
# 	 Lat: 51.0365153, Lon: 3.7219079
#
# {'artwork_subject': 'Onze-Lieve-Vrouw met Kind', 'artwork_type': 'bust', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0531263, Lon: 3.7166835
#
# {'artist:wikidata': 'Q630353', 'artist_name': 'Isidore De Rudder', 'artwork_type': 'statue', 'historic': 'memorial', 'image': 'https://commons.wikimedia.org/wiki/File:Jan_Frans_Willems.jpg', 'mapillary': '3767939519982878', 'material': 'marble;granite', 'memorial': 'statue', 'name': 'Jan Frans Willems', 'start_date': '1899', 'subject:wikidata': 'Q983184', 'subject:wikipedia': 'nl:Jan Frans Willems', 'tourism': 'artwork', 'wheelchair': 'yes', 'wikimedia_commons': 'Category:Jan-Frans Willems monument in Ghent'}
# Jan Frans Willems (None)
# 	 Lat: 51.0533554, Lon: 3.7255669
#
# {'addr:city': 'Gent', 'addr:housenumber': '35', 'addr:postcode': '9000', 'addr:street': 'Bargiekaai', 'name': 'Ecohostel Andromeda', 'phone': '+32 486 67 80 33', 'tourism': 'hostel', 'website': 'http://www.ecohostel.be'}
# Ecohostel Andromeda (None)
# 	 Lat: 51.0592566, Lon: 3.7065254
#
# {'name': 'Orion', 'phone': '+32 9 395 12 95', 'tourism': 'hotel', 'website': 'http://www.hotel-orion.be/'}
# Orion (None)
# 	 Lat: 51.0294743, Lon: 3.7198793
#
# {'artwork_type': 'statue', 'image': 'https://images.mapillary.com/uKoubx0t7N31ACMyR33GAV/thumb-2048.jpg', 'mapillary': '1399240333783238', 'name': '1856 Edward Anseele 1938', 'subject:wikidata': 'Q984045', 'tourism': 'artwork', 'wikidata': 'Q55463547'}
# 1856 Edward Anseele 1938 (None)
# 	 Lat: 51.0477916, Lon: 3.7294909
#
# {'OnroerendErfgoed:criteria': 'M', 'addr:street': 'Vrouwebroersstraat', 'description': 'Pand of Klooster en Kerk van de Geschoeide Karmelieten', 'heritage': '4', 'heritage:operator': 'OnroerendErfgoed', 'heritage:website': 'https://inventaris.onroerenderfgoed.be/dibe/relict/26093', 'historic': 'monastery', 'name': 'Caermersklooster', 'ref:OnroerendErfgoed': '26093', 'tourism': 'museum', 'wikidata': 'Q1858032', 'wikimedia_commons': 'File:Klooster_Geschoeide_Karmelieten.jpg'}
# Caermersklooster (None)
# 	 Lat: 51.0585842, Lon: 3.7223293
#
# {'addr:housenumber': '75', 'addr:street': 'Hoogpoort', 'brand': 'Best Western', 'brand:wikidata': 'Q830334', 'name': 'Best Western', 'tourism': 'hotel'}
# Best Western (None)
# 	 Lat: 51.0545875, Lon: 3.7262414
#
# {'name': 'Quai Des Arts', 'tourism': 'gallery'}
# Quai Des Arts (None)
# 	 Lat: 51.0564784, Lon: 3.7325583
#
# {'artist:wikidata': 'Q14517521', 'artist:wikipedia': 'nl:Walter De Buck', 'artist_name': 'Walter De Buck', 'artwork_type': 'sculpture', 'material': 'bronze', 'name': 'Skaters', 'tourism': 'artwork', 'website': 'https://www.walterdebuck.be/'}
# Skaters (None)
# 	 Lat: 51.0489145, Lon: 3.7469076
#
# {'board_type': 'history', 'description': 'geschiedenis over het gebouw', 'information': 'board', 'tourism': 'information', 'wikimedia_commons': 'File:Gent-Plateau-Rozier-Beschermd-Monument-Info.jpeg'}
# None (None)
# 	 Lat: 51.0461445, Lon: 3.7247328
#
# {'addr:housenumber': '21', 'addr:street': 'Sint-Michielsplein', 'contact:email': 'info@hosteluppelink.com', 'contact:phone': '+32 9 279 44 77', 'name': 'Uppelink', 'tourism': 'hostel', 'website': 'https://www.hosteluppelink.com/'}
# Uppelink (None)
# 	 Lat: 51.0539650, Lon: 3.7197903
#
# {'board_type': 'map', 'information': 'board', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0461200, Lon: 3.7275551
#
# {'tourism': 'viewpoint'}
# None (None)
# 	 Lat: 51.0442371, Lon: 3.6840449
#
# {'addr:city': 'Gent', 'addr:housenumber': '138', 'addr:postcode': '9000', 'addr:street': 'Koningin Astridlaan', 'contact:email': 'info@carltongent.be', 'contact:phone': '+32 9 222 88 36', 'contact:website': 'http://www.carltongent.be/', 'name': 'Carlton', 'tourism': 'hotel'}
# Carlton (None)
# 	 Lat: 51.0364208, Lon: 3.7139965
#
# {'name': "13:00 o'clock Hostel", 'tourism': 'hostel'}
# 13:00 o'clock Hostel (None)
# 	 Lat: 51.0508381, Lon: 3.7232097
#
# {'addr:city': 'Gent', 'addr:housenumber': '35', 'addr:street': 'Filips van Arteveldestraat', 'contact:email': 'info@kabahostel.be', 'contact:phone': '+32 9 233 53 33', 'name': 'Kaba Hostel', 'tourism': 'hostel', 'website': 'http://kabahostel.be'}
# Kaba Hostel (None)
# 	 Lat: 51.0503033, Lon: 3.7350839
#
# {'name': 'Hotel Erasmus', 'tourism': 'hotel', 'website': 'http://www.erasmushotel.be/'}
# Hotel Erasmus (None)
# 	 Lat: 51.0549446, Lon: 3.7179457
#
# {'name': 'Hotel de Flandre', 'tourism': 'hotel', 'website': 'http://www.hoteldeflandre.be/'}
# Hotel de Flandre (None)
# 	 Lat: 51.0548248, Lon: 3.7181044
#
# {'addr:housenumber': '87', 'addr:street': 'Sint-Jacobsnieuwstraat', 'name': 'Hotel Cathedral', 'tourism': 'hotel', 'website': 'http://www.hotelcathedral.be/'}
# Hotel Cathedral (None)
# 	 Lat: 51.0546548, Lon: 3.7300653
#
# {'artist_name': 'Pol Cosmo', 'artwork_type': 'graffiti', 'image': 'https://i.imgur.com/p1y9iLL.jpg', 'name': 'Muurschildering 2 bijen', 'start_date': '2016', 'tourism': 'artwork', 'website': 'https://www.polcosmo.com/'}
# Muurschildering 2 bijen (None)
# 	 Lat: 51.0515304, Lon: 3.7432505
#
# {'addr:housenumber': '16', 'addr:postcode': '9000', 'addr:street': 'Stoppelstraat', 'email': 'studio16@online.be', 'internet_access': 'wlan', 'name': 'studio16', 'name:nl': 'studio16', 'operator': 'Ivette Leroy', 'tourism': 'hostel'}
# studio16 (None)
# 	 Lat: 51.0497444, Lon: 3.7162731
#
# {'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0422258, Lon: 3.7308573
#
# {'addr:city': 'Gent', 'addr:housenumber': '57', 'addr:postcode': '9000', 'addr:street': 'Vlierstraat', 'guest_house': 'bed_and_breakfast', 'internet_access': 'wlan', 'name': "Su'ro", 'phone': '+32 9 330 39 56', 'rooms': '2', 'tourism': 'guest_house', 'website': 'http://www.suro.be'}
# Su'ro (None)
# 	 Lat: 51.0332412, Lon: 3.7264919
#
# {'addr:housenumber': '66', 'addr:street': 'Zwijnaardsesteenweg', 'name': 'Garden in the City', 'tourism': 'guest_house', 'website': 'http://www.gardeninthecity.be/'}
# Garden in the City (None)
# 	 Lat: 51.0348635, Lon: 3.7257172
#
# {'addr:city': 'Gent', 'addr:country': 'BE', 'addr:housenumber': '40', 'addr:postcode': '9000', 'addr:street': 'Rabotstraat', 'internet_access': 'wlan', 'internet_access:fee': 'yes', 'name': 'Atlas B&B', 'rooms': '4', 'tourism': 'guest_house', 'website': 'https://atlas.gent/', 'wheelchair': 'limited'}
# Atlas B&B (None)
# 	 Lat: 51.0580372, Lon: 3.7141842
#
# {'amenity': 'shelter', 'board_type': 'nature', 'information': 'board', 'map_size': 'site', 'map_type': 'scheme', 'shelter_type': 'weather_shelter', 'tourism': 'information'}
# None (shelter)
# 	 Lat: 51.0541216, Lon: 3.6741015
#
# {'board_type': 'nature', 'check_date': '2022-10-10', 'information': 'map', 'map_size': 'site', 'map_type': 'scheme', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0579137, Lon: 3.6861418
#
# {'amenity': 'shelter', 'board_type': 'nature', 'information': 'board', 'map_size': 'site', 'map_type': 'scheme', 'shelter_type': 'weather_shelter', 'tourism': 'information'}
# None (shelter)
# 	 Lat: 51.0656450, Lon: 3.6864736
#
# {'board_type': 'wildlife', 'information': 'board', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0641476, Lon: 3.6775684
#
# {'information': 'map', 'map_size': 'site', 'map_type': 'scheme', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0667095, Lon: 3.6821893
#
# {'amenity': 'shelter', 'board_type': 'nature', 'check_date': '2021-11-02', 'information': 'map', 'map_size': 'site', 'map_type': 'scheme', 'shelter_type': 'weather_shelter', 'tourism': 'information'}
# None (shelter)
# 	 Lat: 51.0669928, Lon: 3.6829065
#
# {'contact:phone': '+32 495 15 47 42', 'contact:website': 'http://bedandbreakfast.be/bed_and_breakfast/detail/Belgium/Oost-Vlaanderen/A_place_to_be', 'guest_house': 'bed_and_breakfast', 'tourism': 'guest_house'}
# None (None)
# 	 Lat: 51.0580140, Lon: 3.7486304
#
# {'name': 'Astoria', 'stars': '3', 'tourism': 'hotel', 'website': 'http://www.astoria.be/', 'wheelchair': 'yes'}
# Astoria (None)
# 	 Lat: 51.0333368, Lon: 3.7170169
#
# {'artist_name': 'Ann Veronica Janssens', 'artwork_type': 'sculpture', 'description': 'https://photos.app.goo.gl/MyMjmVarbFVxD76D9', 'image': 'https://images.mapillary.com/q2qXEl42ttC1Tyrp4InqeW/thumb-2048.jpg', 'mapillary': '507581203715440', 'name': 'HD 400', 'tourism': 'artwork'}
# HD 400 (None)
# 	 Lat: 51.0542795, Lon: 3.7221536
#
# {'artist_name': 'Ayşe Erkmen', 'artwork_type': 'sculpture', 'image': 'https://images.mapillary.com/60oxXR5UydkuoAIiOWf3fR/thumb-2048.jpg', 'mapillary': '507059550333874', 'name': 'Broche', 'tourism': 'artwork'}
# Broche (None)
# 	 Lat: 51.0549252, Lon: 3.7220403
#
# {'name': 'Monasterium Poortackere', 'tourism': 'hotel'}
# Monasterium Poortackere (None)
# 	 Lat: 51.0524955, Lon: 3.7166961
#
# {'addr:city': 'Gent', 'addr:housenumber': '16', 'addr:postcode': '9000', 'addr:street': 'Graslei', 'brand': '1898 The Post', 'email': 'welcome@1898thepost.com', 'internet_access': 'wlan', 'internet_access:fee': 'yes', 'name': '1898 The Post', 'operator': '1898 The Post', 'phone': '+32 9 391 53 79', 'rooms': '38', 'tourism': 'hotel', 'website': 'https://1898thepost.com/'}
# 1898 The Post (None)
# 	 Lat: 51.0541384, Lon: 3.7209354
#
# {'artist_name': 'Pitaya', 'name': 'De Blauwe Vogels', 'tourism': 'artwork'}
# De Blauwe Vogels (None)
# 	 Lat: 51.0524171, Lon: 3.7206542
#
# {'artist_name': 'Jessica Diamond', 'name': 'Mystic Leaves', 'tourism': 'artwork', 'wikidata': 'Q28767989'}
# Mystic Leaves (None)
# 	 Lat: 51.0501208, Lon: 3.7231290
#
# {'artist_name': 'Michaël Borremans', 'artwork_type': 'statue', 'description': 'https://photos.app.goo.gl/iby1yppVJHydYGpY7', 'image': 'https://commons.wikimedia.org/wiki/File:Micha%C3%ABl_Borremans,_%27De_Passanten%27,_Gent.jpg', 'mapillary': '207700004319546', 'name': 'De Passanten', 'tourism': 'artwork', 'wikidata': 'Q88685206'}
# De Passanten (None)
# 	 Lat: 51.0484221, Lon: 3.7288163
#
# {'addr:housenumber': '26', 'internet_access': 'wlan', 'name': 'Suite Dreams Ghent', 'name:en': 'Suite Dreams Ghent', 'phone': '+32 494 18 60 10', 'tourism': 'apartment'}
# Suite Dreams Ghent (None)
# 	 Lat: 51.0566348, Lon: 3.7136900
#
# {'artwork_type': 'statue', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0570914, Lon: 3.7132793
#
# {'artwork_type': 'bust', 'tourism': 'artwork', 'wikidata': 'Q107520664'}
# None (None)
# 	 Lat: 51.0316384, Lon: 3.7174814
#
# {'artwork_type': 'statue', 'name': 'De Stervende Gladiator', 'tourism': 'artwork', 'wikidata': 'Q107483355'}
# De Stervende Gladiator (None)
# 	 Lat: 51.0469115, Lon: 3.7316650
#
# {'information': 'map', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0506636, Lon: 3.7262592
#
# {'artwork_type': 'sculpture', 'image': 'https://images.mapillary.com/EI5XOn3mC5E7nhduBfZ7RD/thumb-2048.jpg', 'mapillary': '839015380155253', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0398998, Lon: 3.7337924
#
# {'addr:housenumber': '42', 'addr:street': 'Verkortingstraat', 'email': 'info@touristflat-dewulf.be', 'name': 'Touristflat Dewulf', 'phone': '+32 9 238 29 58', 'tourism': 'apartment', 'website': 'http://touristflat-dewulf.be/'}
# Touristflat Dewulf (None)
# 	 Lat: 51.0644656, Lon: 3.7507625
#
# {'artwork_type': 'statue', 'image': 'https://i.imgur.com/mVCU7bg.jpg', 'name': 'Willem I', 'tourism': 'artwork'}
# Willem I (None)
# 	 Lat: 51.0531579, Lon: 3.7297221
#
# {'name': 'graffiti skateboarder', 'name:ru': 'Граффити "Скейтбордист"', 'tourism': 'artwork'}
# graffiti skateboarder (None)
# 	 Lat: 51.0478846, Lon: 3.7280999
#
# {'artist_name': 'Johan Meirlaen', 'artwork_type': 'statue', 'material': 'bronze', 'name': 'Het rode meisje', 'name:nl': 'Het rode meisje', 'name:ru': 'Сидящая на балке женщина', 'tourism': 'artwork', 'website': 'https://loreleie.jouwweb.be/'}
# Het rode meisje (None)
# 	 Lat: 51.0533708, Lon: 3.7347864
#
# {'name': 'Pillows Grand Hotel Reylof', 'tourism': 'hotel', 'website': 'https://www.pillowshotels.com/ghent/'}
# Pillows Grand Hotel Reylof (None)
# 	 Lat: 51.0546739, Lon: 3.7151020
#
# {'name': 'The Lord', 'tourism': 'hotel'}
# The Lord (None)
# 	 Lat: 51.0355590, Lon: 3.7130251
#
# {'layer': '1', 'tourism': 'viewpoint'}
# None (None)
# 	 Lat: 51.0534908, Lon: 3.6920951
#
# {'tourism': 'viewpoint'}
# None (None)
# 	 Lat: 51.0519885, Lon: 3.6858507
#
# {'addr:housenumber': '19', 'addr:street': 'Sint-Denijslaan', 'breakfast': 'yes', 'name': 'Adoma', 'stars': '3', 'tourism': 'hotel', 'website': 'https://www.hotel-adoma.be/'}
# Adoma (None)
# 	 Lat: 51.0338060, Lon: 3.7146984
#
# {'addr:street': 'Toekomststraat', 'name': 'Wasserij Gent', 'tourism': 'attraction'}
# Wasserij Gent (None)
# 	 Lat: 51.0506363, Lon: 3.7466046
#
# {'tourism': 'attraction'}
# None (None)
# 	 Lat: 51.0560947, Lon: 3.7289486
#
# {'addr:city': 'Gent', 'addr:housenumber': '63', 'addr:postcode': '9000', 'addr:street': 'Hoogpoort', 'name': 'NH Gent Belfort', 'operator': 'NH Hotel Group', 'phone': '+32 9 233 33 31', 'tourism': 'hotel', 'website': 'https://www.nh-hotels.com/hotel/nh-gent-belfort'}
# NH Gent Belfort (None)
# 	 Lat: 51.0548504, Lon: 3.7255649
#
# {'artist_name': 'Marf', 'artwork_subject': 'Memorial', 'artwork_type': 'installation', 'material': 'metal', 'name': 'Gedenkbeeld vermiste personen', 'start_date': '1996', 'tourism': 'artwork'}
# Gedenkbeeld vermiste personen (None)
# 	 Lat: 51.0575938, Lon: 3.7207801
#
# {'artist:wikidata': 'Q21901266', 'artist_name': 'Hyuro', 'artwork_type': 'mural', 'start_date': '2019', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0568297, Lon: 3.7271787
#
# {'name': 'Onderbergen', 'tourism': 'hotel', 'website': 'http://www.hotelonderbergen.be/'}
# Onderbergen (None)
# 	 Lat: 51.0502095, Lon: 3.7189525
#
# {'tourism': 'information'}
# None (None)
# 	 Lat: 51.0545442, Lon: 3.7164790
#
# {'artwork_type': 'statue', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0589075, Lon: 3.7164433
#
# {'tourism': 'information'}
# None (None)
# 	 Lat: 51.0537973, Lon: 3.7029828
#
# {'tourism': 'information'}
# None (None)
# 	 Lat: 51.0573258, Lon: 3.7083108
#
# {'artwork_type': 'statue', 'historic': 'memorial', 'subject:wikidata': 'Q711213', 'tourism': 'artwork', 'wikidata': 'Q89422343'}
# None (None)
# 	 Lat: 51.0569807, Lon: 3.7098181
#
# {'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0564660, Lon: 3.7140815
#
# {'contact:website': 'http://www.walpoort.com/', 'name': 'De Walpoort', 'tourism': 'guest_house', 'wheelchair': 'no'}
# De Walpoort (None)
# 	 Lat: 51.0486793, Lon: 3.7268451
#
# {'artwork_type': 'sculpture', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0530135, Lon: 3.7199988
#
# {'information': 'board', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0564623, Lon: 3.7338238
#
# {'name': 'Gravensteen', 'tourism': 'hotel'}
# Gravensteen (None)
# 	 Lat: 51.0560219, Lon: 3.7197324
#
# {'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0503020, Lon: 3.7381840
#
# {'name': 'Cosy room', 'tourism': 'guest_house'}
# Cosy room (None)
# 	 Lat: 51.0631767, Lon: 3.7252892
#
# {'artwork_type': 'statue', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0619007, Lon: 3.7242992
#
# {'name': 'Graaf', 'tourism': 'guest_house'}
# Graaf (None)
# 	 Lat: 51.0605957, Lon: 3.7205543
#
# {'addr:housenumber': '2', 'addr:street': 'Abraham Voortmanstraat', 'email': 'receptie@denbriel.be', 'internet_access': 'wlan', 'internet_access:fee': 'no', 'name': 'Den Briel', 'phone': '+32 9 430 20 00', 'tourism': 'hotel', 'website': 'https://denbriel.be/'}
# Den Briel (None)
# 	 Lat: 51.0655991, Lon: 3.7218871
#
# {'information': 'guidepost', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0559655, Lon: 3.7357507
#
# {'artist_name': 'ROA', 'artwork_type': 'mural', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0358590, Lon: 3.7233723
#
# {'addr:housenumber': '35', 'addr:street': 'Karel Lodewijk Ledeganckstraat', 'email': 'info.gum@ugent.be', 'fee': 'yes', 'name': 'Gents Universiteitsmuseum', 'name:en': 'Ghent University Museum', 'name:fr': 'Musée de l’Université de Gand', 'opening_hours': 'Mo, Tu, Th, Fr 09:30-17:30; Sa-Su, PH 10:00-18:00; We off', 'operator': 'Universtiteit Gent', 'phone': '+32 9 264 49 30', 'short_name': 'GUM', 'subject': 'science', 'tourism': 'museum', 'website': 'https://www.gum.gent', 'wikidata': 'Q100263681'}
# Gents Universiteitsmuseum (None)
# 	 Lat: 51.0359404, Lon: 3.7232481
#
# {'artwork_type': 'statue', 'material': 'metal', 'name': 'Excelsior', 'tourism': 'artwork'}
# Excelsior (None)
# 	 Lat: 51.0564217, Lon: 3.7307489
#
# {'name': 'Trianon', 'tourism': 'hotel'}
# Trianon (None)
# 	 Lat: 51.0353481, Lon: 3.7072564
#
# {'artwork_type': 'graffiti', 'description': 'https://photos.app.goo.gl/WJ9NMzXa3zFhKPJr6', 'image': 'https://images.mapillary.com/ks2N6BXqymg5Hg7haJ3bvI/thumb-2048.jpg', 'mapillary': '2954350084823207', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0596661, Lon: 3.7385855
#
# {'artwork_type': 'graffiti', 'image': 'https://images.mapillary.com/JEbcbQjQ1DJaZjzYe87Xfi/thumb-2048.jpg', 'mapillary': '792231688380527', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0597254, Lon: 3.7388084
#
# {'artwork_type': 'graffiti', 'description': 'https://photos.app.goo.gl/LjhYs3SyxzU6u2mz8', 'image': 'https://images.mapillary.com/EIJiQw0WF5AMoBQ6g708yY/thumb-2048.jpg', 'mapillary': '497961044889412', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0599178, Lon: 3.7387576
#
# {'artist_name': 'Keeppunchingjoe', 'artwork_type': 'graffiti', 'image': 'https://images.mapillary.com
#
# {'artwork_type': 'graffiti', 'image': 'https://images.mapillary.com/PXiuQWgYyJaIq8qGf3zDoz/thumb-2048.jpghttps://images.mapillary.com/PXiuQWgYyJaIq8qGf3zDoz/thumb-2048.jpg', 'mapillary': '1453142915026895', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0309195, Lon: 3.7562713
#
# {'artist_name': 'Bue, Malf, Quatch, Resto', 'artwork_type': 'graffiti', 'image': 'https://images.mapillary.com/9ldSRyvFTK7b20aa2SiwCh/thumb-2048.jpg', 'mapillary': '479569253352648', 'start_date': '2020', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0309816, Lon: 3.7563371
#
# {'artist_name': 'Pavo Real', 'artwork_type': 'graffiti', 'image': 'https://images.mapillary.com/OsRYhXREDxGPtska4z8u3s/thumb-2048.jpg', 'mapillary': '523065288882979', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0310725, Lon: 3.7564112
#
# {'artist_name': 'Resto', 'artwork_type': 'graffiti', 'description': 'https://photos.app.goo.gl/VKsAMAhFqe6vdqRV6', 'image': 'https://images.mapillary.com/Nzm9g5EvF9uXVs8WOONRtk/thumb-2048.jpg', 'mapillary': '223535799192974', 'start_date': '2020', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0311090, Lon: 3.7563951
#
# {'artwork_type': 'graffiti', 'image': 'https://images.mapillary.com/PYb4BqZepsi4aQGbh4gX5E/thumb-2048.jpg', 'mapillary': '3799620930164500', 'name': 'Scarpulla', 'tourism': 'artwork'}
# Scarpulla (None)
# 	 Lat: 51.0311033, Lon: 3.7563409
#
# {'artist_name': 'CA', 'artwork_type': 'graffiti', 'image': 'https://images.mapillary.com/3LEv0QgbkT9UapShsymYxL/thumb-2048.jpg', 'mapillary': '167910615258204', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0312615, Lon: 3.7560702
#
# {'artwork_type': 'graffiti', 'image': 'https://images.mapillary.com/ePENvXSzLEeW4oUe1me5mS/thumb-2048.jpg', 'mapillary': '567003230946639', 'name': 'Pxase', 'tourism': 'artwork'}
# Pxase (None)
# 	 Lat: 51.0310694, Lon: 3.7553531
#
# {'artwork_type': 'graffiti', 'image': 'https://images.mapillary.com/WbEJzSUFHfjiouB1mbw93T/thumb-2048.jpg', 'mapillary': '3824667704312782', 'name': 'Tintelun', 'tourism': 'artwork'}
# Tintelun (None)
# 	 Lat: 51.0524101, Lon: 3.7548160
#
# {'artwork_type': 'graffiti', 'image': 'https://images.mapillary.com/Lpe0tkBjotYORAzONEPZUN/thumb-2048.jpg', 'mapillary': '931601194289220', 'name': 'Tintelun', 'tourism': 'artwork'}
# Tintelun (None)
# 	 Lat: 51.0523434, Lon: 3.7547548
#
# {'artwork_type': 'painting', 'image': 'https://i.imgur.com/dJqaw1s.jpg', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0507819, Lon: 3.7043372
#
# {'artwork_type': 'relief', 'image': 'https://i.imgur.com/XSfqiAr.jpg', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0508611, Lon: 3.7044203
#
# {'information': 'board', 'inscription': 'Rolschaatsen', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0469694, Lon: 3.6890526
#
# {'direction': '0', 'tourism': 'viewpoint'}
# None (None)
# 	 Lat: 51.0538758, Lon: 3.7205430
#
# {'artist_name': 'Aäron Willem', 'artwork_type': 'mural', 'image': 'https://i.imgur.com/O8DWcDZ.jpg', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0588206, Lon: 3.7018776
#
# {'artist_name': 'Paul De Vigne', 'artwork_type': 'statue', 'image': 'https://upload.wikimedia.org/wikipedia/commons/a/ae/Louis_Van_Houtte_standbeeld_in_Gentbrugge_door_Paul_De_Vigne_15-10-2009_15-10-06.JPG', 'inscription': '1810-1876', 'name': 'Louis Van Houtte', 'subject': 'Louis Van Houtte', 'subject:wikidata': 'Q2073003', 'tourism': 'artwork'}
# Louis Van Houtte (None)
# 	 Lat: 51.0429316, Lon: 3.7460979
#
# {'image': 'https://i.imgur.com/18nEPsd.jpg', 'information': 'board', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0422746, Lon: 3.6857978
#
# {'image': 'https://i.imgur.com/Mn65Gdd.jpg', 'tourism': 'map'}
# None (None)
# 	 Lat: 51.0409827, Lon: 3.6879086
#
# {'board_type': 'nature', 'image': 'https://i.imgur.com/wBtr3JK.jpg', 'information': 'board', 'name': 'Welkom in het park Halfweg', 'tourism': 'information'}
# Welkom in het park Halfweg (None)
# 	 Lat: 51.0522466, Lon: 3.6923222
#
# {'board_type': 'welcome_sign', 'description': 'Overblijfsel van de voormalige pralinefabriek', 'historic': 'yes', 'information': 'board', 'name': 'Daskalidès Pralines', 'tourism': 'information'}
# Daskalidès Pralines (None)
# 	 Lat: 51.0514878, Lon: 3.6991984
#
# {'board_type': 'notice', 'image': 'https://i.imgur.com/FngAwFM.jpg', 'information': 'board', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0533349, Lon: 3.6809309
#
# {'artwork_type': 'mural', 'image': 'https://i.imgur.com/tdOBBXq.jpg', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0594005, Lon: 3.7219512
#
# {'mural_painting': 'yes', 'street_art': 'yes', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0595980, Lon: 3.7345318
#
# {'artist_name': 'Andreas Welin', 'artwork_type': 'mural', 'name': 'De voorbijganger', 'tourism': 'artwork'}
# De voorbijganger (None)
# 	 Lat: 51.0471695, Lon: 3.7554338
#
# {'addr:housenumber': '32', 'addr:street': 'Driepikkelstraat', 'information': 'visitor_centre', 'name': 'Bezoekerscentrum De Bourgoyen', 'operator': 'Natuurpunt', 'tourism': 'information', 'website': 'https://www.natuurpunt.be/bezoekerscentrum/bezoekerscentrum-de-bourgoyen'}
# Bezoekerscentrum De Bourgoyen (None)
# 	 Lat: 51.0669791, Lon: 3.6822671
#
# {'artist_name': 'Marc Nagtzaam', 'artwork_type': 'installation', 'image': 'https://i.imgur.com/i5MV12u.jpg', 'tourism': 'artwork', 'website': 'https://persruimte.stad.gent/166618-nieuwe-kunstwerken-voor-ledebergse-standaertsite-en-de-papegaaiwijk'}
# None (None)
# 	 Lat: 51.0374929, Lon: 3.7452784
#
# {'artist_name': 'Marc Nagtzaam', 'artwork_type': 'installation', 'image': 'https://i.imgur.com/RVovax0.jpg', 'tourism': 'artwork', 'website': 'https://persruimte.stad.gent/166618-nieuwe-kunstwerken-voor-ledebergse-standaertsite-en-de-papegaaiwijk'}
# None (None)
# 	 Lat: 51.0366699, Lon: 3.7459275
#
# {'artist_name': 'Atelier Joep Van Lieshou', 'artwork_type': 'installation', 'image': 'https://i.imgur.com/ciORFFg.jpg', 'name': 'De Grote AVL-man', 'tourism': 'artwork', 'website': 'https://cultuur.stad.gent/nl/street-art/de-grote-avl-man'}
# De Grote AVL-man (None)
# 	 Lat: 51.0346388, Lon: 3.7370280
#
# {'artist_name': 'Ismail Farouk', 'artwork_type': 'installation', 'image': 'https://i.imgur.com/3crFqzM.jpg', 'name': 'SMAAKLIK', 'source': 'https://www.tineheyse.be/smaaklik_op_nieuwe_centrumplein_ledeberg', 'start_date': '2016-05-27', 'tourism': 'artwork', 'website': 'https://stad.gent/nl/ledeberg-leeft/gerealiseerde-deelprojecten-van-ledeberg-leeft/het-centrumplein-terug-een-volwaardige-ontmoetingsplek'}
# SMAAKLIK (None)
# 	 Lat: 51.0347367, Lon: 3.7400922
#
# {'tourism': 'information'}
# None (None)
# 	 Lat: 51.0563842, Lon: 3.7400299
#
# {'information': 'board', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0563830, Lon: 3.7399606
#
# {'artwork_type': 'installation', 'name': 'Japanse waterstolp', 'tourism': 'artwork'}
# Japanse waterstolp (None)
# 	 Lat: 51.0603257, Lon: 3.7265754
#
# {'artwork_type': 'statue', 'name': 'Geketende Slaven', 'tourism': 'artwork', 'wikidata': 'Q107482668'}
# Geketende Slaven (None)
# 	 Lat: 51.0384843, Lon: 3.7243047
#
# {'artwork_type': 'statue', 'name': 'Edmond van Beveren', 'tourism': 'artwork', 'wikidata': 'Q107520656'}
# Edmond van Beveren (None)
# 	 Lat: 51.0382920, Lon: 3.7254558
#
# {'artwork_type': 'statue', 'material': 'stone', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0427017, Lon: 3.7576442
#
# {'addr:city': 'Gent', 'addr:housenumber': '14', 'addr:postcode': '9000', 'addr:street': 'Lange Steenstraat', 'email': 'info@kunsthal.gent', 'museum': 'art', 'name': 'Kunsthal Gent', 'opening_hours': 'Sa-Su 11:00-18:00', 'tourism': 'museum', 'website': 'https://kunsthal.gent/'}
# Kunsthal Gent (None)
# 	 Lat: 51.0587825, Lon: 3.7217775
#
# {'addr:housenumber': '54', 'addr:street': 'Vlaanderenstraat', 'guest_house': 'bed_and_breakfast', 'name': 'La Ducale', 'tourism': 'guest_house'}
# La Ducale (None)
# 	 Lat: 51.0505757, Lon: 3.7295871
#
# {'artwork_type': 'statue', 'name': 'Pierke', 'tourism': 'artwork'}
# Pierke (None)
# 	 Lat: 51.0559448, Lon: 3.7249149
#
# {'board_type': 'art', 'information': 'board', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0388360, Lon: 3.7231628
#
# {'artwork_type': 'statue', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0465538, Lon: 3.7113327
#
# {'name': 'Hotel Castel', 'tourism': 'hotel'}
# Hotel Castel (None)
# 	 Lat: 51.0371616, Lon: 3.7118793
#
# {'artwork_type': 'installation', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0592706, Lon: 3.7170614
#
# {'artwork_type': 'sculpture', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0446442, Lon: 3.7252870
#
# {'name:en': 'GHENT CASTLE', 'name:nl': 'Gravensteen', 'tourism': 'attraction'}
# None (None)
# 	 Lat: 51.0569223, Lon: 3.7212597
#
# {'addr:housenumber': '1/001', 'addr:postcode': '9000', 'addr:street': 'Concrdiastraat', 'name': 'Nederlants', 'tourism': 'apartment'}
# Nederlants (None)
# 	 Lat: 51.0606066, Lon: 3.7116531
#
# {'bicycle': 'yes', 'information': 'board', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0302729, Lon: 3.7293052
#
# {'artist_name': 'Roa', 'artwork_type': 'graffiti', 'image': 'https://i.imgur.com/tXNUpJP.jpg', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0518463, Lon: 3.7432238
#
# {'artwork_type': 'graffiti', 'image': 'https://i.imgur.com/rlYysNf.jpg', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0519449, Lon: 3.7430361
#
# {'artwork_type': 'graffiti', 'image': 'https://i.imgur.com/Ax7S33B.jpg', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0518193, Lon: 3.7431072
#
# {'information': 'board', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0320496, Lon: 3.7369509
#
# {'artwork_type': 'installation', 'name': 'De Boei', 'tourism': 'artwork'}
# De Boei (None)
# 	 Lat: 51.0652219, Lon: 3.7370222
#
# {'artwork_type': 'mural', 'image': 'https://photos.app.goo.gl/EPuv2RLF2eMxsYGF7', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0495818, Lon: 3.7444478
#
# {'name:en': 'City Garden rooms', 'tourism': 'hotel'}
# None (None)
# 	 Lat: 51.0554303, Lon: 3.7186960
#
# {'name:en': 'City Garden Rooms', 'tourism': 'hotel'}
# None (None)
# 	 Lat: 51.0553985, Lon: 3.7187001
#
# {'artwork_type': 'mural', 'image': 'https://i.imgur.com/KQOPWmB.jpg', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0492623, Lon: 3.7444201
#
# {'artwork_type': 'mural', 'image': 'https://i.imgur.com/gQrLsFo.jpg', 'tourism': 'artwork'}
# None (None)
# 	 Lat: 51.0491653, Lon: 3.7445247
#
# {'addr:city': 'Gent', 'addr:housenumber': '33', 'addr:postcode': '9000', 'addr:street': 'Brabantdam', 'email': 'hello@yalohotel.com', 'name': 'Yalo Hotel', 'phone': '+32 9 395 92 00', 'tourism': 'hotel', 'website': 'https://www.yalohotel.com'}
# Yalo Hotel (None)
# 	 Lat: 51.0505667, Lon: 3.7284378
#
# {'image': 'https://i.imgur.com/CFNrmro.jpg', 'information': 'board', 'tourism': 'information'}
# None (None)
# 	 Lat: 51.0643494, Lon: 3.7064052

# %%
print(len(output))
print(output[0])
# Out:
# 362
# {'addr:housenumber': '43', 'addr:postcode': '9000', 'addr:street': 'Jozef Guislainstraat', 'email': 'info@museumdrguislain.be', 'fee': 'yes', 'name': 'Museum Dr. Guislain', 'opening_hours': 'Tu-Fr 09:00-17:00; Sa-Su 13:00-17:00', 'phone': '+32 9 398 69 50', 'toilets:wheelchair': 'yes', 'tourism': 'museum', 'website': 'http://www.museumdrguislain.be', 'wheelchair': 'yes', 'wikidata': 'Q2934898', 'wikimedia_commons': 'Category:Museum_Dr_Guislain', 'coordinate': {'latitude': 51.0668514, 'longitude': 3.7033213}}

# %%
for rel in result.relations:
    tags = rel.tags
    print(rel.members)
    print(f"{tags['name'] if 'name' in tags else None} ({tags['amenity'] if 'amenity' in tags else None})")
    print(f"\t Lat: {rel.center_lat}, Lon: {rel.center_lon}")
    print()

    #output_line = rel.tags
    #output_line['coordinate'] = {'latitude': rel.center_lat, 'longitude': rel.center_lat}

    #output.append(output_line)
# Out:
# [<overpy.RelationWay ref=1058302460 role=None>, <overpy.RelationWay ref=52199456 role=None>, <overpy.RelationWay ref=440889549 role=None>, <overpy.RelationWay ref=700006491 role=None>, <overpy.RelationWay ref=111695946 role=None>, <overpy.RelationWay ref=700006490 role=None>]
# Overpoortstraat (None)
# 	 Lat: None, Lon: None

# %%
for way in result.ways:
    tags = way.tags
    if 'amenity' in tags and tags['amenity'] in ['arts_centre', 'exhibition_centre', 'cinema', 'events_venue','library','toy_library','music_school','school','university','fountain','music_venue']:
        print(f"{tags['name'] if 'name' in tags else None} ({tags['amenity'] if 'amenity' in tags else None})")
        print(f"\t Lat: {nodes[0].lat}, Lon: {nodes[0].lon}")
        nodes = way.get_nodes(resolve_missing=True)
    
        output_line = way.tags
        output_line['coordinate']={'latitude': float(nodes[0].lat), 'longitude': float(nodes[0].lon)}

        output.append(output_line)

# %%
import json

with open('pois.json', 'w+') as fp:
    json.dump(output, fp)
